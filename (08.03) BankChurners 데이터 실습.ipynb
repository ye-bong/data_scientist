# %%
import pandas as pd
import numpy as np

import os

# %%
cur_dir = os.getcwd()
print("cur_dir : ", cur_dir, "\n")
# Out:
# cur_dir :  C:\Users\leah5\Documents\study

# %%
# 현재 프로세스의 작업 디렉토리 확인
cur_dir = os.getcwd()
print("cur_dir : ", cur_dir, "\n")

# 현재 작업파일의 경로에 있는 리스트 확인 -> 리스트로 반환
dir_list = os.listdir(cur_dir)
print("dir_list : ", dir_list, "\n")

# 특정 경로의 폴더(디렉토리) 생성
# os.mkdir(cur_dir + "/dataset")

# 지정한 파일의 이름을 변경
# os.rename('경로/파일명1', '경로/파일명2')
# print(os.path.exists('경로/파일명2'))

# 지정된 경로의 디렉토리를 순차적으로 탐색 -> 주로 for문과 활용
for curDir, dirs, files in os.walk(cur_dir): 
    print(curDir, dirs, files)
    for f in files:
        print(os.path.join(curDir, f))
# Out:
# cur_dir :  C:\Users\leah5\Documents\study
#
# dir_list :  ['(08.02)chapter 1. 데이터 전처리-샘플 데이터.ipynb', '(08.03)BankChurners 데이터 실습.ipynb', '(08.03)강사님_코드.ipynb', '(08.03)데이터전처리_모델학습.ipynb', '.ipynb_checkpoints', 'BankChurners.csv', 'Dropout', '테이블명세서_cards.csv']
#
# C:\Users\leah5\Documents\study ['.ipynb_checkpoints', 'Dropout'] ['(08.02)chapter 1. 데이터 전처리-샘플 데이터.ipynb', '(08.03)BankChurners 데이터 실습.ipynb', '(08.03)강사님_코드.ipynb', '(08.03)데이터전처리_모델학습.ipynb', 'BankChurners.csv', '테이블명세서_cards.csv']
# C:\Users\leah5\Documents\study\(08.02)chapter 1. 데이터 전처리-샘플 데이터.ipynb
# C:\Users\leah5\Documents\study\(08.03)BankChurners 데이터 실습.ipynb
# C:\Users\leah5\Documents\study\(08.03)강사님_코드.ipynb
# C:\Users\leah5\Documents\study\(08.03)데이터전처리_모델학습.ipynb
# C:\Users\leah5\Documents\study\BankChurners.csv
# C:\Users\leah5\Documents\study\테이블명세서_cards.csv
# ...

# %%
data_list = os.listdir('C:\\Users\\leah5\\Documents\\study')
print("데이터셋 목록(data_list) : ", data_list)
# Out:
# 데이터셋 목록(data_list) :  ['(08.02)chapter 1. 데이터 전처리-샘플 데이터.ipynb', '(08.03)BankChurners 데이터 실습.ipynb', '(08.03)강사님_코드.ipynb', '(08.03)데이터전처리_모델학습.ipynb', '.ipynb_checkpoints', 'BankChurners.csv', 'Dropout', '테이블명세서_cards.csv']

# %%
df = pd.read_csv('C:\\Users\\leah5\\Documents\\study\\BankChurners.csv', index_col = 0).reset_index()
df_info = pd.read_csv('C:\\Users\\leah5\\Documents\\study\\테이블명세서_cards.csv', index_col = 0, encoding='cp949').reset_index()

# %%
df_info
# Out:
#                          변수명                        변수설명     변수타입
# 0                  CLIENTNUM                   고객 고유 식별자      int
# 1             Attrition_Flag                    고객 이탈 여부     Bool
# 2               Customer_Age                       고객 나이      int
# 3                     Gender                          성별   object
# 4            Dependent_count                     부양 가족 수      int
# 5            Education_Level                    고객 학업 수준   object
# 6             Marital_Status                    고객 결혼 여부   object
# 7            Income_Category                    고객 소득 범주   object
# 8              Card_Category               고객이 보유한 카드 유형   object
# 9             Months_on_book                      예약 개월수      int
# 10  Total_Relationship_Count              신용카드 제공업체 관계 수      int
# 11    Months_Inactive_12_mon  지난 12개월 동안 고객의 비활성 상태 개월 수      int
# 12     Contacts_Count_12_mon    지난 12개월 동안 고객이 보유한 연락처 수      int
# ...

# %%
df.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10124 non-null  object
#  2   Customer_Age                                                                                                                        10114 non-null  float64
# ...

# %%
# 컬럼별 중복 제거 및 개수

columns_info = dict()
columns = df.columns
for col in columns:
    columns_info[col] = len(df[col].unique())
    
columns_info
# Out:
# {'CLIENTNUM': 10127,
#  'Attrition_Flag': 3,
#  'Customer_Age': 46,
#  'Gender': 3,
#  'Dependent_count': 7,
#  'Education_Level': 8,
#  'Marital_Status': 5,
#  'Income_Category': 7,
#  'Card_Category': 5,
#  'Months_on_book': 45,
#  'Total_Relationship_Count': 7,
#  'Months_Inactive_12_mon': 8,
#  'Contacts_Count_12_mon': 8,
#  'Credit_Limit': 6202,
#  'Total_Revolving_Bal': 1973,
#  'Avg_Open_To_Buy': 6805,
#  'Total_Amt_Chng_Q4_Q1': 1157,
#  'Total_Trans_Amt': 5027,
#  'Total_Trans_Ct': 127,
#  'Total_Ct_Chng_Q4_Q1': 831,
#  'Avg_Utilization_Ratio': 965,
#  'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1': 1589,
#  'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2': 641}

# %%
# 이상한 칼럼 삭제
df.drop(labels=['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
                'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2',
                ],axis=1,inplace=True)

# %%
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer          45.0      M              3.0
# 1      818770008  Existing Customer          49.0      F              5.0
# 2      713982108  Existing Customer          51.0      M              3.0
# 3      769911858  Existing Customer          40.0      F              4.0
# 4      709106358  Existing Customer          40.0      M              3.0
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer          50.0      M              2.0
# 10123  710638233  Attrited Customer          41.0      M              2.0
# 10124  716506083  Attrited Customer          44.0      F              1.0
# 10125  717406983  Attrited Customer          30.0      M              2.0
# 10126  714337233  Attrited Customer          43.0      F              2.0
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
null_cnt_df = pd.DataFrame(df.isnull().sum()).rename(columns = {0:'null_count'}).reset_index()
null_cnt_df['null_ratio'] = round(null_cnt_df['null_count']/len(df) * 100, 2)
null_cnt_df
# Out:
#                        index  null_count  null_ratio
# 0                  CLIENTNUM           0        0.00
# 1             Attrition_Flag           3        0.03
# 2               Customer_Age          13        0.13
# 3                     Gender           8        0.08
# 4            Dependent_count          40        0.39
# 5            Education_Level          15        0.15
# 6             Marital_Status          10        0.10
# 7            Income_Category           7        0.07
# 8              Card_Category           9        0.09
# 9             Months_on_book          10        0.10
# 10  Total_Relationship_Count           8        0.08
# 11    Months_Inactive_12_mon           4        0.04
# 12     Contacts_Count_12_mon           8        0.08
# 13              Credit_Limit          12        0.12
# 14       Total_Revolving_Bal          18        0.18
# 15           Avg_Open_To_Buy          14        0.14
# 16      Total_Amt_Chng_Q4_Q1          16        0.16
# ...

# %%
# 결측치 처리
# target 변수의 결측치 유무 확인
df[df['Attrition_Flag'].isnull() == True]
# Out:
#       CLIENTNUM Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 7434  789472833            NaN          42.0      F              2.0
# 7442  714408933            NaN          44.0      M              4.0
# 7451  758178558            NaN          44.0      F              3.0
#
#      Education_Level Marital_Status Income_Category Card_Category  \
# 7434         College       Divorced  Less than $40K          Blue
# 7442        Graduate         Single    $80K - $120K          Blue
# 7451        Graduate         Single         Unknown          Blue
#
#       Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 7434            33.0  ...                     3.0                    1.0
# 7442            36.0  ...                     2.0                    2.0
# 7451            37.0  ...                     2.0                    1.0
#
#       Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 7434        2283.0               1690.0            593.0
# ...

# %%
# target 변수에 결측이 있는 row 제거
df_remove = df[df['Attrition_Flag'].isnull() == False]

# %%
df_remove = df_remove.dropna(axis = 0, thresh = 2)

# %%
df_remove = df_remove.dropna(axis=0, how='all')

# %%
df_remove
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer          45.0      M              3.0
# 1      818770008  Existing Customer          49.0      F              5.0
# 2      713982108  Existing Customer          51.0      M              3.0
# 3      769911858  Existing Customer          40.0      F              4.0
# 4      709106358  Existing Customer          40.0      M              3.0
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer          50.0      M              2.0
# 10123  710638233  Attrited Customer          41.0      M              2.0
# 10124  716506083  Attrited Customer          44.0      F              1.0
# 10125  717406983  Attrited Customer          30.0      M              2.0
# 10126  714337233  Attrited Customer          43.0      F              2.0
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
# Dependent_count 칼럼 삭제
df_remove.drop(labels=['Dependent_count'],axis=1,inplace=True)

# %%
# 결측값 대치
columns_type_list = df_remove.columns.to_series().groupby(df_remove.dtypes).groups
columns_type_list = {types.name : list(cols) for types, cols in columns_type_list.items()}

# %%
float_list = columns_type_list['float64']
object_list = columns_type_list['object']

# %%
# float 타입 컬럼 모두 각 컬럼의 평균값으로 결측치 대치
for col in float_list:
    means = df_remove[col].mean()
    df_remove[col] = df_remove[col].fillna(means)

# %%
# object 타입 컬럼 모두 각 컬럼의 최빈값으로 대치
for col in object_list:
    most_freq_val = df_remove[col].mode()[0]
    df_remove[col] = df_remove[col].fillna(most_freq_val)

# %%
df_remove.isna().sum()
# Out:
# CLIENTNUM                   0
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %%
# 데이터 시각화
import matplotlib.pyplot as plt
import matplotlib
# 그래프 타이틀 한글 출력
matplotlib.rcParams['font.family'] ='Malgun Gothic'

# 그래프 사이즈 지정
plt.rcParams['figure.figsize'] = [12, 8]

# %%
Target = df_remove['Attrition_Flag'].value_counts()

plt.pie(Target, labels = Target.index, autopct = '%2.1f%%')
plt.title('Target(Attrition_Flag) 변수 비율')
plt.show()

# %%
import seaborn as sns

# %%
sns.countplot(data = df_remove, x = 'Gender', hue = 'Attrition_Flag', hue_order = ['Existing Customer', 'Attrited Customer'])
plt.xticks(ticks = [0, 1], labels = ['Female', 'Male'])
plt.ylabel('고객 수')
plt.title('Target(Attrition_Flag)별 성비')
plt.show()

# %%
# 카드 유형에 따른 target 비율
card_df = df_remove.groupby(by = ['Card_Category', 'Attrition_Flag']).size().reset_index().pivot(columns = 'Attrition_Flag',
                                                                                              index = 'Card_Category',
                                                                                              values = 0)

# %%
card_df
# Out:
# Attrition_Flag  Attrited Customer  Existing Customer
# Card_Category
# Blue                         1518               7915
# Gold                           21                 95
# Platinum                        5                 15
# Silver                         82                473

# %%
card_df_sum = card_df.sum(axis = 1)
card_df_sorted = card_df_sum.sort_values(ascending = True)
card_df.loc[card_df_sorted.index].plot(kind = 'barh', stacked = True)

plt.title('고객이 보유한 카드 유형에 따른 고객 이탈자 수 (Target 비율)')
plt.xlabel("고객 수")
plt.ylabel('카드 유형')
plt.show()

# %% [markdown]
# - Blue 유형의 카드를 가진 고객이 압도적으로 많아 예측률에 큰 영향을 못 줄 것으로 보임

# %%
fig = sns.displot(data = df_remove, x = 'Customer_Age', kde = True)
fig.fig.set_size_inches(14, 8)
plt.xlabel('연령대')
plt.ylabel('고객 수')
plt.show()

# %%
# 히트맵 그리기
plt.figure(figsize = (7, 5))
sns.heatmap(df_remove.corr(), annot = True, cmap = 'coolwarm', fmt = '.2f')
plt.title('고객 이탈자 여부 - 상관계수')
plt.show()
# Out:
# C:\Users\leah5\AppData\Local\Temp\ipykernel_6176\4146131670.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_remove.corr(), annot = True, cmap = 'coolwarm', fmt = '.2f')
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# C:\ProgramData\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 변수 간 연관성 검토
sns.set_style('whitegrid')
sns.scatterplot(data=df_remove, x='Months_on_book', y='Customer_Age')
# Out:
# <Axes: xlabel='Months_on_book', ylabel='Customer_Age'>

# %%
sns.scatterplot(data=df_remove, x='Avg_Open_To_Buy', y='Credit_Limit')
# Out:
# <Axes: xlabel='Avg_Open_To_Buy', ylabel='Credit_Limit'>

# %%
sns.scatterplot(data=df_remove, x='Total_Trans_Ct', y='Total_Trans_Amt')
# Out:
# <Axes: xlabel='Total_Trans_Ct', ylabel='Total_Trans_Amt'>

# %%
# 삭제 필요한 컬럼 리스트
need_to_remove_col = ['Months_on_book','Avg_Open_To_Buy','Card_Category']

# %%
df_remove.drop(need_to_remove_col, axis = 1, inplace = True)

# %%
df_remove['Attrition_Flag'].value_counts()
# Out:
# Existing Customer    8498
# Attrited Customer    1626
# Name: Attrition_Flag, dtype: int64

# %%
# 모델링 - 라벨 인코딩
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

from sklearn import preprocessing

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, auc, classification_report

import copy

# %%
df = copy.deepcopy(df_remove)

encoder = LabelEncoder()
df['Attrition_Flag'] = encoder.fit_transform(df['Attrition_Flag'])
df['Education_Level'] = encoder.fit_transform(df['Education_Level'])
df['Gender'] = encoder.fit_transform(df['Gender'])
df['Marital_Status'] = encoder.fit_transform(df['Marital_Status'])
df['Income_Category'] = encoder.fit_transform(df['Income_Category'])
# df['Card_Category'] = encoder.fit_transform(df['Card_Category'])

# %%
df
# Out:
#        CLIENTNUM  Attrition_Flag  Customer_Age  Gender  Education_Level  \
# 0      768805383               1          45.0       1                3
# 1      818770008               1          49.0       0                2
# 2      713982108               1          51.0       1                2
# 3      769911858               1          40.0       0                3
# 4      709106358               1          40.0       1                5
# ...          ...             ...           ...     ...              ...
# 10122  772366833               1          50.0       1                2
# 10123  710638233               0          41.0       1                6
# 10124  716506083               0          44.0       0                3
# 10125  717406983               0          30.0       1                2
# 10126  714337233               0          43.0       0                2
#
#        Marital_Status  Income_Category  Total_Relationship_Count  \
# ...

# %%
# target 변수와 input 변수 나누기
X = df.drop(['Attrition_Flag', 'CLIENTNUM'], axis = 1)
y = df['Attrition_Flag']

# %%
# 스케일링
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state= 777)

# %%
scaler = preprocessing.MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
# 모델 생성

# 모델 불러오기, 정의
DT = DecisionTreeClassifier()
# 학습 데이터로 모델(Decision Tree) 학습
DT.fit(X_train, y_train)


# 학습된 모델로 test 결과값 출력
y_pred = DT.predict(X_test)

# %%
# 예측 결과 확인
y_test = y_test.astype(int).tolist()
y_pred = y_pred.astype(int).tolist()

model_report = classification_report(y_test, y_pred) # 요약본
print(model_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.84      0.82       341
#            1       0.97      0.96      0.96      1684
#
#     accuracy                           0.94      2025
#    macro avg       0.89      0.90      0.89      2025
# weighted avg       0.94      0.94      0.94      2025

# %%
accuracy = round(accuracy_score(y_test, y_pred), 3)
precision = round(precision_score(y_test, y_pred, average = 'macro'), 3) # 각각 0,1,2 precision의 평균
recall = round(recall_score(y_test, y_pred, average = 'macro'), 3) # 0,1,2 recall을 한방에 구함

print('accuracy : ', accuracy, '\n',
      'precision : ', precision, '\n',
      'recall : ', recall)
# Out:
# accuracy :  0.939
#  precision :  0.887
#  recall :  0.899

# %%
# ROC 그래프 그리기
Y_scores = DT.predict_proba(X_test)
# fpr, tpr, threshold = roc_curve(y_test, y_pred, pos_label = 2)
fpr, tpr, threshold = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

plt.title('Decision Tree Classifier')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.title('ROC Curve of NAIVE BAYES')
plt.show()
